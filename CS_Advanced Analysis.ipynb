# %%
# !pip install xgboost
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn import metrics
# Out:
# Requirement already satisfied: xgboost in c:\users\dell\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\lib\site-packages (from xgboost) (1.23.5)
# Requirement already satisfied: scipy in c:\users\dell\anaconda3\lib\site-packages (from xgboost) (1.10.0)
# C:\Users\Dell\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# C:\Users\Dell\AppData\Local\Temp\ipykernel_17272\2298029850.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("C:/Users/Dell/OneDrive/Desktop/Research Analysis/CS_Advanced.csv")
df.head()
# Out:
#   Hospital Main Unit  Age  Gender Ethnicity Highest Educational Level  \
# 0      DMH   Inward    29  Female   Sinhala        Diploma in Nursing
# 1      DMH   Inward    25  Female   Sinhala        Diploma in Nursing
# 2      DMH   Inward    28  Female   Sinhala             BSc. Nursing
# 3      DMH   Inward    43  Female   Sinhala    BSc. (Hons) in Nursing
# 4      DMH   Inward    28  Female   Sinhala        Diploma in Nursing
#
#       Marital Status Have Children?  No. of Children have  \
# 0            Married            Yes                     1
# 1  In a relationship   Not relevant                   999
# 2            Married             No                   999
# 3            Married            Yes                     3
# 4  In a relationship   Not relevant                   999
#
#   Age of the youngest child  ... Frequency of involving patient emergencies  \
# 0            Less than 1 yr  ...                                       High
# 1              Not relevant  ...                                  Very high
# 2              Not relevant  ...                                       High
# 3                 4 - 7 yrs  ...                                        Low
# 4              Not relevant  ...                                  Very high
#
#   Frequency of exposure to patients death  \
# 0                                Very low
# 1                               Very high
# 2                                    High
# 3                                     Low
# 4                                Very low
#
#   Frequency of facing struggles with patients Cleanliness     Safety  \
# 0                                    Very low        High       High
# 1                                   Very high   Very high  Very high
# 2                                        High        High       High
# 3                                         Low        High       High
# 4                                     Average        High       High
#
#   Availability and accessibility Sufficient rest areas        BMI  P/N Ratio  \
# 0                           High                  High  17.777778  20.000000
# 1                      Very high             Very high  25.299376   2.058824
# 2                        Average               Average  22.313278   2.000000
# 3                           High                   Low  25.631168   1.750000
# 4                           High                  High  22.666667   1.764706
#
#   CS_Score
# 0       42
# 1       48
# 2       32
# 3       45
# 4       42
#
# [5 rows x 38 columns]

# %%
df.shape
# Out:
# (368, 38)

# %%
cat_cols = ['Highest Educational Level', 'Daily travelling Distance', 'Total Working Hours in a Week', 'Night Shifts per Month']  # replace with your actual categorical columns

for col in cat_cols:
    print(f"Levels for {col}: {df[col].unique()}")
# Out:
# Levels for Highest Educational Level: ['Diploma in Nursing' 'BSc. Nursing ' 'BSc. (Hons) in Nursing']
# Levels for Daily travelling Distance: ['More than 10 km' 'Less than 1 km' '5 - 10 km' '1 - 5 km']
# Levels for Total Working Hours in a Week: ['63 - 84' '42 - 63' '>84 ' '<42 ']
# Levels for Night Shifts per Month: ['<5 ' '5 to 10' '>10 ']

# %%
ordinal_variables = ['Highest Educational Level','Monthly Family Income','Monthly Salary Income', 'Daily travelling Distance', 'Mental Health Rate','Physical Health Rate','Hours of Sleeping','Work Experience in this Hospital','Full work Experience as a Nurse','Total Working Hours in a Week','Night Shifts per Month','Support from other Nurses','Support from the Minor Staff','Support from the Hospital Administration','Support from the family','Support from friends','Support from the Superiors','Frequency of involving patient emergencies','Frequency of exposure to patients death','Frequency of facing struggles with patients','Cleanliness','Safety','Availability and accessibility','Sufficient rest areas']

ordinal_variables_order = {
    'Highest Educational Level': ['Diploma in Nursing', 'BSc. Nursing ', 'BSc. (Hons) in Nursing'],
    'Monthly Family Income': ['Less than Rs.75,000', 'Rs.75,000 – Rs.100,000', 'Rs.100,000 - Rs.200,000','More than Rs.200,000'],
    'Monthly Salary Income': ['Less than 75,000', '75,000 - 100,000', 'More than 100,000'],
    'Daily travelling Distance': ['Less than 1 km', '1 - 5 km', '5 - 10 km','More than 10 km'],
    'Mental Health Rate': ['Poor','Fair','Good','Very Good','Excellent'],
    'Physical Health Rate': ['Poor','Fair','Good','Very Good','Excellent'],
    'Hours of Sleeping': ['Less than 3 hours','3 - 5 hours','5 - 7 hours','More than 7 hours'],
    'Work Experience in this Hospital': ['Less than 5 years','5 - 10 years','10 - 20 years','More than 20 years'],
    'Full work Experience as a Nurse': ['Less than 5 years','5 - 10 years','10 - 20 years','More than 20 years'],
    'Total Working Hours in a Week': ['<42 ','42 - 63','63 - 84','>84 '],
    'Night Shifts per Month': ['<5 ','5 to 10','>10 '],
    'Relationship with the Superiors': ['Very low','Low','Average','High','Very high'],
    'Support from other Nurses': ['Very low','Low','Average','High','Very high'],
    'Support from the Minor Staff': ['Very low','Low','Average','High','Very high'],
    'Support from the Hospital Administration': ['Average','High','Very high'],
    'Support from the family': ['Very low','Low','Average','High','Very high'],
    'Support from friends': ['Very low','Low','Average','High','Very high'],
    'Support from the Superiors': ['Very low','Low','Average','High','Very high'],
    'Frequency of involving patient emergencies': ['Very low','Low','Average','High','Very high'],
    'Frequency of exposure to patients death': ['Very low','Low','Average','High','Very high'],
    'Frequency of facing struggles with patients': ['Very low','Low','Average','High','Very high'],
    'Cleanliness': ['Very low','Low','Average','High','Very high'],
    'Safety': ['Very low','Low','Average','High','Very high'],
    'Availability and accessibility': ['Very low','Low','Average','High','Very high'],
    'Sufficient rest areas': ['Very low','Low','Average','High','Very high']
}

# Convert ordinal variables to categorical with custom order
for ordinal_var, custom_order in ordinal_variables_order.items():
    df[ordinal_var] = pd.Categorical(df[ordinal_var], categories=custom_order, ordered=True)

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Hospital                                       0
# Main Unit                                      0
# Age                                            0
# Gender                                         0
# Ethnicity                                      0
# Highest Educational Level                      0
# Marital Status                                 0
# Have Children?                                 0
# No. of Children have                           0
# Age of the youngest child                      0
# Monthly Family Income                          0
# Daily travelling Distance                      0
# Transport Mode                                 0
# Mental Health Rate                             0
# Physical Health Rate                           0
# Hours of Sleeping                              0
# Work Experience in this Hospital               0
# Full work Experience as a Nurse                0
# Total Working Hours in a Week                  0
# Night Shifts per Month                         0
# Monthly Salary Income                          0
# Relationship with the Superiors                0
# Support from other Nurses                      0
# Support from the Minor Staff                   0
# Support from the Hospital Administration       0
# Support from the family                        0
# Support from friends                           0
# Support from the Superiors                     0
# Frequency of involving patient emergencies     0
# Frequency of exposure to patients death        0
# Frequency of facing struggles with patients    0
# Cleanliness                                    0
# Safety                                         0
# Availability and accessibility                 0
# Sufficient rest areas                          0
# BMI                                            0
# P/N Ratio                                      0
# CS_Score                                       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 368 entries, 0 to 367
# Data columns (total 38 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Hospital                                     368 non-null    object
#  1   Main Unit                                    368 non-null    object
#  2   Age                                          368 non-null    int64
#  3   Gender                                       368 non-null    object
#  4   Ethnicity                                    368 non-null    object
#  5   Highest Educational Level                    368 non-null    category
#  6   Marital Status                               368 non-null    object
#  7   Have Children?                               368 non-null    object
#  8   No. of Children have                         368 non-null    int64
#  9   Age of the youngest child                    368 non-null    object
#  10  Monthly Family Income                        368 non-null    category
#  11  Daily travelling Distance                    368 non-null    category
#  12  Transport Mode                               368 non-null    object
#  13  Mental Health Rate                           368 non-null    category
#  14  Physical Health Rate                         368 non-null    category
#  15  Hours of Sleeping                            368 non-null    category
#  16  Work Experience in this Hospital             368 non-null    category
#  17  Full work Experience as a Nurse              368 non-null    category
#  18  Total Working Hours in a Week                368 non-null    category
#  19  Night Shifts per Month                       368 non-null    category
#  20  Monthly Salary Income                        368 non-null    category
#  21  Relationship with the Superiors              368 non-null    category
#  22  Support from other Nurses                    368 non-null    category
#  23  Support from the Minor Staff                 368 non-null    category
#  24  Support from the Hospital Administration     368 non-null    category
#  25  Support from the family                      368 non-null    category
#  26  Support from friends                         368 non-null    category
#  27  Support from the Superiors                   368 non-null    category
#  28  Frequency of involving patient emergencies   368 non-null    category
#  29  Frequency of exposure to patients death      368 non-null    category
#  30  Frequency of facing struggles with patients  368 non-null    category
#  31  Cleanliness                                  368 non-null    category
#  32  Safety                                       368 non-null    category
#  33  Availability and accessibility               368 non-null    category
#  34  Sufficient rest areas                        368 non-null    category
#  35  BMI                                          368 non-null    float64
#  36  P/N Ratio                                    368 non-null    float64
#  37  CS_Score                                     368 non-null    int64
# dtypes: category(25), float64(2), int64(3), object(8)
# memory usage: 51.3+ KB

# %%
# Get list of categorical variables
s = (df.dtypes =="object")
object_cols = list(s[s].index)
print("Categorical variables:")
print(object_cols)
# Out:
# Categorical variables:
# ['Hospital', 'Main Unit', 'Gender', 'Ethnicity', 'Marital Status', 'Have Children?', 'Age of the youngest child', 'Transport Mode']

# %%
# Get list of ordinal variables
o = (df.dtypes =="category")
cat_cols = list(o[o].index)
print("Ordinal variables:")
print(cat_cols)
# Out:
# Ordinal variables:
# ['Highest Educational Level', 'Monthly Family Income', 'Daily travelling Distance', 'Mental Health Rate', 'Physical Health Rate', 'Hours of Sleeping', 'Work Experience in this Hospital', 'Full work Experience as a Nurse', 'Total Working Hours in a Week', 'Night Shifts per Month', 'Monthly Salary Income', 'Relationship with the Superiors', 'Support from other Nurses', 'Support from the Minor Staff', 'Support from the Hospital Administration', 'Support from the family', 'Support from friends', 'Support from the Superiors', 'Frequency of involving patient emergencies', 'Frequency of exposure to patients death', 'Frequency of facing struggles with patients', 'Cleanliness', 'Safety', 'Availability and accessibility', 'Sufficient rest areas']

# %%
# Make copy to avoid changing original data 
label_data = df.copy()

# Apply one-hot encoding to each column with categorical data
one_hot_data = pd.get_dummies(label_data, columns=object_cols)

label_data = one_hot_data

# Now 'one_hot_data' contains one-hot encoded features
label_data.head()
# Out:
#    Age Highest Educational Level  No. of Children have  \
# 0   29        Diploma in Nursing                     1
# 1   25        Diploma in Nursing                   999
# 2   28             BSc. Nursing                    999
# 3   43    BSc. (Hons) in Nursing                     3
# 4   28        Diploma in Nursing                   999
#
#     Monthly Family Income Daily travelling Distance Mental Health Rate  \
# 0  Rs.75,000 – Rs.100,000           More than 10 km               Good
# 1  Rs.75,000 – Rs.100,000            Less than 1 km               Good
# 2     Less than Rs.75,000                 5 - 10 km               Good
# 3  Rs.75,000 – Rs.100,000                 5 - 10 km               Fair
# 4  Rs.75,000 – Rs.100,000            Less than 1 km               Poor
#
#   Physical Health Rate Hours of Sleeping Work Experience in this Hospital  \
# 0                 Good       5 - 7 hours                Less than 5 years
# 1                 Good       5 - 7 hours                Less than 5 years
# 2                 Poor       5 - 7 hours                     5 - 10 years
# 3                 Fair       3 - 5 hours                    10 - 20 years
# 4                 Poor       5 - 7 hours                Less than 5 years
#
#   Full work Experience as a Nurse  ... Age of the youngest child_15 - 18 yrs  \
# 0               Less than 5 years  ...                                 False
# 1               Less than 5 years  ...                                 False
# 2               Less than 5 years  ...                                 False
# 3                   10 - 20 years  ...                                 False
# 4                    5 - 10 years  ...                                 False
#
#   Age of the youngest child_4 - 7 yrs Age of the youngest child_8 - 14 yrs  \
# 0                               False                                False
# 1                               False                                False
# 2                               False                                False
# 3                                True                                False
# 4                               False                                False
#
#   Age of the youngest child_Above 18 yrs  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#   Age of the youngest child_Less than 1 yr  \
# 0                                     True
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#   Age of the youngest child_Not relevant Transport Mode_Car/Motorcycle  \
# 0                                  False                         False
# 1                                   True                         False
# 2                                   True                         False
# 3                                  False                         False
# 4                                   True                         False
#
#   Transport Mode_Private bus/van Transport Mode_Public transport   \
# 0                          False                             True
# 1                          False                            False
# 2                          False                             True
# 3                          False                             True
# 4                          False                            False
#
#   Transport Mode_Walking
# 0                  False
# 1                   True
# 2                  False
# 3                  False
# 4                   True
#
# [5 rows x 62 columns]

# %%
label_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 368 entries, 0 to 367
# Data columns (total 62 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Age                                          368 non-null    int64
#  1   Highest Educational Level                    368 non-null    category
#  2   No. of Children have                         368 non-null    int64
#  3   Monthly Family Income                        368 non-null    category
#  4   Daily travelling Distance                    368 non-null    category
#  5   Mental Health Rate                           368 non-null    category
#  6   Physical Health Rate                         368 non-null    category
#  7   Hours of Sleeping                            368 non-null    category
#  8   Work Experience in this Hospital             368 non-null    category
#  9   Full work Experience as a Nurse              368 non-null    category
#  10  Total Working Hours in a Week                368 non-null    category
#  11  Night Shifts per Month                       368 non-null    category
#  12  Monthly Salary Income                        368 non-null    category
#  13  Relationship with the Superiors              368 non-null    category
#  14  Support from other Nurses                    368 non-null    category
#  15  Support from the Minor Staff                 368 non-null    category
#  16  Support from the Hospital Administration     368 non-null    category
#  17  Support from the family                      368 non-null    category
#  18  Support from friends                         368 non-null    category
#  19  Support from the Superiors                   368 non-null    category
#  20  Frequency of involving patient emergencies   368 non-null    category
#  21  Frequency of exposure to patients death      368 non-null    category
#  22  Frequency of facing struggles with patients  368 non-null    category
#  23  Cleanliness                                  368 non-null    category
#  24  Safety                                       368 non-null    category
#  25  Availability and accessibility               368 non-null    category
#  26  Sufficient rest areas                        368 non-null    category
#  27  BMI                                          368 non-null    float64
#  28  P/N Ratio                                    368 non-null    float64
#  29  CS_Score                                     368 non-null    int64
#  30  Hospital_DMH                                 368 non-null    bool
#  31  Hospital_LRH                                 368 non-null    bool
#  32  Hospital_NCI                                 368 non-null    bool
#  33  Hospital_NHSL                                368 non-null    bool
#  34  Main Unit_ICU                                368 non-null    bool
#  35  Main Unit_Inward                             368 non-null    bool
#  36  Main Unit_OPD                                368 non-null    bool
#  37  Main Unit_Theater                            368 non-null    bool
#  38  Gender_Female                                368 non-null    bool
#  39  Gender_Male                                  368 non-null    bool
#  40  Ethnicity_Burgher                            368 non-null    bool
#  41  Ethnicity_Muslim                             368 non-null    bool
#  42  Ethnicity_Sinhala                            368 non-null    bool
#  43  Ethnicity_Tamil                              368 non-null    bool
#  44  Marital Status_In a relationship             368 non-null    bool
#  45  Marital Status_Married                       368 non-null    bool
#  46  Marital Status_Single                        368 non-null    bool
#  47  Marital Status_Spouse has passed away        368 non-null    bool
#  48  Have Children?_No                            368 non-null    bool
#  49  Have Children?_Not relevant                  368 non-null    bool
#  50  Have Children?_Yes                           368 non-null    bool
#  51  Age of the youngest child_1 - 3 yrs          368 non-null    bool
#  52  Age of the youngest child_15 - 18 yrs        368 non-null    bool
#  53  Age of the youngest child_4 - 7 yrs          368 non-null    bool
#  54  Age of the youngest child_8 - 14 yrs         368 non-null    bool
#  55  Age of the youngest child_Above 18 yrs       368 non-null    bool
#  56  Age of the youngest child_Less than 1 yr     368 non-null    bool
#  57  Age of the youngest child_Not relevant       368 non-null    bool
#  58  Transport Mode_Car/Motorcycle                368 non-null    bool
#  59  Transport Mode_Private bus/van               368 non-null    bool
#  60  Transport Mode_Public transport              368 non-null    bool
#  61  Transport Mode_Walking                       368 non-null    bool
# dtypes: bool(32), category(25), float64(2), int64(3)
# memory usage: 39.8 KB

# %%
from sklearn.preprocessing import OrdinalEncoder

# Initialize the encoder
encoder = OrdinalEncoder()

# List of ordinal variables
ordinal_cols = ['Highest Educational Level', 'Monthly Family Income', 'Daily travelling Distance', 'Mental Health Rate', 'Physical Health Rate', 'Hours of Sleeping', 'Work Experience in this Hospital', 'Full work Experience as a Nurse', 'Total Working Hours in a Week', 'Night Shifts per Month', 'Monthly Salary Income', 'Relationship with the Superiors', 'Support from other Nurses', 'Support from the Minor Staff', 'Support from the Hospital Administration', 'Support from the family', 'Support from friends', 'Support from the Superiors', 'Frequency of involving patient emergencies', 'Frequency of exposure to patients death', 'Frequency of facing struggles with patients', 'Cleanliness', 'Safety', 'Availability and accessibility', 'Sufficient rest areas']

# Assume 'df' is your DataFrame
for col in ordinal_cols:
    label_data[col] = encoder.fit_transform(label_data[[col]])

label_data.head()
# Out:
#    Age  Highest Educational Level  No. of Children have  \
# 0   29                        2.0                     1
# 1   25                        2.0                   999
# 2   28                        1.0                   999
# 3   43                        0.0                     3
# 4   28                        2.0                   999
#
#    Monthly Family Income  Daily travelling Distance  Mental Health Rate  \
# 0                    3.0                        3.0                 2.0
# 1                    3.0                        2.0                 2.0
# 2                    0.0                        1.0                 2.0
# 3                    3.0                        1.0                 1.0
# 4                    3.0                        2.0                 3.0
#
#    Physical Health Rate  Hours of Sleeping  Work Experience in this Hospital  \
# 0                   2.0                1.0                               2.0
# 1                   2.0                1.0                               2.0
# 2                   3.0                1.0                               1.0
# 3                   1.0                0.0                               0.0
# 4                   3.0                1.0                               2.0
#
#    Full work Experience as a Nurse  ...  \
# 0                              2.0  ...
# 1                              2.0  ...
# 2                              2.0  ...
# 3                              0.0  ...
# 4                              1.0  ...
#
#    Age of the youngest child_15 - 18 yrs  Age of the youngest child_4 - 7 yrs  \
# 0                                  False                                False
# 1                                  False                                False
# 2                                  False                                False
# 3                                  False                                 True
# 4                                  False                                False
#
#    Age of the youngest child_8 - 14 yrs  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
#    Age of the youngest child_Above 18 yrs  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    Age of the youngest child_Less than 1 yr  \
# 0                                      True
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#    Age of the youngest child_Not relevant  Transport Mode_Car/Motorcycle  \
# 0                                   False                          False
# 1                                    True                          False
# 2                                    True                          False
# 3                                   False                          False
# 4                                    True                          False
#
#    Transport Mode_Private bus/van  Transport Mode_Public transport   \
# 0                           False                              True
# 1                           False                             False
# 2                           False                              True
# 3                           False                              True
# 4                           False                             False
#
#    Transport Mode_Walking
# 0                   False
# 1                    True
# 2                   False
# 3                   False
# 4                    True
#
# [5 rows x 62 columns]

# %%
label_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 368 entries, 0 to 367
# Data columns (total 62 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Age                                          368 non-null    int64
#  1   Highest Educational Level                    368 non-null    float64
#  2   No. of Children have                         368 non-null    int64
#  3   Monthly Family Income                        368 non-null    float64
#  4   Daily travelling Distance                    368 non-null    float64
#  5   Mental Health Rate                           368 non-null    float64
#  6   Physical Health Rate                         368 non-null    float64
#  7   Hours of Sleeping                            368 non-null    float64
#  8   Work Experience in this Hospital             368 non-null    float64
#  9   Full work Experience as a Nurse              368 non-null    float64
#  10  Total Working Hours in a Week                368 non-null    float64
#  11  Night Shifts per Month                       368 non-null    float64
#  12  Monthly Salary Income                        368 non-null    float64
#  13  Relationship with the Superiors              368 non-null    float64
#  14  Support from other Nurses                    368 non-null    float64
#  15  Support from the Minor Staff                 368 non-null    float64
#  16  Support from the Hospital Administration     368 non-null    float64
#  17  Support from the family                      368 non-null    float64
#  18  Support from friends                         368 non-null    float64
#  19  Support from the Superiors                   368 non-null    float64
#  20  Frequency of involving patient emergencies   368 non-null    float64
#  21  Frequency of exposure to patients death      368 non-null    float64
#  22  Frequency of facing struggles with patients  368 non-null    float64
#  23  Cleanliness                                  368 non-null    float64
#  24  Safety                                       368 non-null    float64
#  25  Availability and accessibility               368 non-null    float64
#  26  Sufficient rest areas                        368 non-null    float64
#  27  BMI                                          368 non-null    float64
#  28  P/N Ratio                                    368 non-null    float64
#  29  CS_Score                                     368 non-null    int64
#  30  Hospital_DMH                                 368 non-null    bool
#  31  Hospital_LRH                                 368 non-null    bool
#  32  Hospital_NCI                                 368 non-null    bool
#  33  Hospital_NHSL                                368 non-null    bool
#  34  Main Unit_ICU                                368 non-null    bool
#  35  Main Unit_Inward                             368 non-null    bool
#  36  Main Unit_OPD                                368 non-null    bool
#  37  Main Unit_Theater                            368 non-null    bool
#  38  Gender_Female                                368 non-null    bool
#  39  Gender_Male                                  368 non-null    bool
#  40  Ethnicity_Burgher                            368 non-null    bool
#  41  Ethnicity_Muslim                             368 non-null    bool
#  42  Ethnicity_Sinhala                            368 non-null    bool
#  43  Ethnicity_Tamil                              368 non-null    bool
#  44  Marital Status_In a relationship             368 non-null    bool
#  45  Marital Status_Married                       368 non-null    bool
#  46  Marital Status_Single                        368 non-null    bool
#  47  Marital Status_Spouse has passed away        368 non-null    bool
#  48  Have Children?_No                            368 non-null    bool
#  49  Have Children?_Not relevant                  368 non-null    bool
#  50  Have Children?_Yes                           368 non-null    bool
#  51  Age of the youngest child_1 - 3 yrs          368 non-null    bool
#  52  Age of the youngest child_15 - 18 yrs        368 non-null    bool
#  53  Age of the youngest child_4 - 7 yrs          368 non-null    bool
#  54  Age of the youngest child_8 - 14 yrs         368 non-null    bool
#  55  Age of the youngest child_Above 18 yrs       368 non-null    bool
#  56  Age of the youngest child_Less than 1 yr     368 non-null    bool
#  57  Age of the youngest child_Not relevant       368 non-null    bool
#  58  Transport Mode_Car/Motorcycle                368 non-null    bool
#  59  Transport Mode_Private bus/van               368 non-null    bool
#  60  Transport Mode_Public transport              368 non-null    bool
#  61  Transport Mode_Walking                       368 non-null    bool
# dtypes: bool(32), float64(27), int64(3)
# memory usage: 97.9 KB

# %%
label_data.to_csv("C:/Users/Dell/OneDrive/Desktop/Research Analysis/label_data.csv", index=False)

# %%
missing_values = label_data.isnull().sum()
print(missing_values)
# Out:
# Age                                       0
# Highest Educational Level                 0
# No. of Children have                      0
# Monthly Family Income                     0
# Daily travelling Distance                 0
#                                          ..
# Age of the youngest child_Not relevant    0
# Transport Mode_Car/Motorcycle             0
# Transport Mode_Private bus/van            0
# Transport Mode_Public transport           0
# Transport Mode_Walking                    0
# Length: 62, dtype: int64

# %%
# Assigning the featurs as X and trarget as y
X= label_data.drop(["CS_Score"],axis =1)
y= label_data["CS_Score"]
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2, random_state=7)

# %%
num_observations_X_train = len(X_train)
print(f"Number of observations in X_train: {num_observations_X_train}")
# Out:
# Number of observations in X_train: 294

# %%
len(y_train)
# Out:
# 294

# %%
num_observations_X_test = len(X_test)
print(f"Number of observations in X_test: {num_observations_X_test}")
# Out:
# Number of observations in X_test: 74

# %%
from sklearn.linear_model import Ridge, Lasso, ElasticNet

# Building pipelines of standard scaler and model for various regressors.
pipeline_lr = Pipeline([("scalar1", StandardScaler()), ("lr_classifier", LinearRegression())])
pipeline_dt = Pipeline([("scalar2", StandardScaler()), ("dt_classifier", DecisionTreeRegressor())])
pipeline_rf = Pipeline([("scalar3", StandardScaler()), ("rf_classifier", RandomForestRegressor())])
pipeline_kn = Pipeline([("scalar4", StandardScaler()), ("kn_classifier", KNeighborsRegressor())])
pipeline_xgb = Pipeline([("scalar5", StandardScaler()), ("xgb_classifier", XGBRegressor())])
pipeline_ridge = Pipeline([("scalar6", StandardScaler()), ("ridge_classifier", Ridge())])
pipeline_lasso = Pipeline([("scalar7", StandardScaler()), ("lasso_classifier", Lasso())])
pipeline_elasticnet = Pipeline([("scalar8", StandardScaler()), ("elasticnet_classifier", ElasticNet())])
pipeline_svr = Pipeline([("scalar9", StandardScaler()), ("svr_classifier", SVR())])  # Add SVR pipeline

# List of all the pipelines
pipelines = [pipeline_lr, pipeline_dt, pipeline_rf, pipeline_kn, pipeline_xgb, pipeline_ridge, pipeline_lasso, pipeline_elasticnet, pipeline_svr]

# Dictionary of pipelines and model types for ease of reference
pipe_dict = {0: "LinearRegression", 1: "DecisionTree", 2: "RandomForest", 3: "KNeighbors", 4: "XGBRegressor", 5: "Ridge", 6: "Lasso", 7: "ElasticNet", 8: "SVR"}  

# Fit the pipelines
for pipe in pipelines:
    pipe.fit(X_train, y_train)

cv_results_rms = []
for i, model in enumerate(pipelines):
    cv_score = cross_val_score(model, X_train, y_train, scoring="neg_root_mean_squared_error", cv=10)
    cv_results_rms.append(cv_score)
    print("%s: %f " % (pipe_dict[i], cv_score.mean()))
# Out:
# LinearRegression: -258329504850.672546
# DecisionTree: -5.580098
# RandomForest: -4.105076
# KNeighbors: -4.465650
# XGBRegressor: -4.413782
# Ridge: -4.560445
# Lasso: -4.334861
# ElasticNet: -4.210596
# SVR: -4.198340

# %%
from sklearn import metrics
import numpy as np
from sklearn.metrics import mean_absolute_percentage_error as MAPE

# List of model names
models = ["LinearRegression", "DecisionTree", "RandomForest", "KNeighbors", "XGBRegressor", "Ridge", "Lasso", "ElasticNet", "SupportVectorRegressor"]

# For each model
for i, model in enumerate(pipelines):
    # Predict on the test data
    pred = model.predict(X_test)
    
    # Print model name
    print("\nModel: ", models[i])
    
    # Print metrics
    #print("R^2:", metrics.r2_score(y_test, pred))
    #print("Adjusted R^2:", 1 - (1-metrics.r2_score(y_test, pred))*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
    #print("MAE:", metrics.mean_absolute_error(y_test, pred))
    #print("MSE:", metrics.mean_squared_error(y_test, pred))
    mape_value = MAPE(y_test, pred)
    print(f"MAPE: {mape_value:.4f}")
    print("RMSE:", np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# Model:  LinearRegression
# MAPE: 0.0946
# RMSE: 4.504208150522344
#
# Model:  DecisionTree
# MAPE: 0.1332
# RMSE: 5.845996551117326
#
# Model:  RandomForest
# MAPE: 0.0788
# RMSE: 3.551976229528449
#
# Model:  KNeighbors
# MAPE: 0.0891
# RMSE: 4.124023225876349
#
# Model:  XGBRegressor
# MAPE: 0.0832
# RMSE: 3.970216854224642
#
# Model:  Ridge
# MAPE: 0.0952
# RMSE: 4.504050844332491
#
# Model:  Lasso
# MAPE: 0.0955
# RMSE: 4.184782548412062
#
# Model:  ElasticNet
# MAPE: 0.0928
# RMSE: 4.106981291345332
#
# Model:  SupportVectorRegressor
# MAPE: 0.0902
# RMSE: 4.060134539053322

# %%
from sklearn import metrics
import numpy as np

# List of model names
models = ["LinearRegression", "DecisionTree", "RandomForest", "KNeighbors", "XGBRegressor", "Ridge", "Lasso", "ElasticNet","SupportVectorRegressor"]

# For each model
for i, model in enumerate(pipelines):
    # Predict on the test data
    pred = model.predict(X_train)
    
    # Print model name
    print("\nModel: ", models[i])
    
    # Print metrics
    #print("R^2:", metrics.r2_score(y_train, pred))
    #print("Adjusted R^2:", 1 - (1-metrics.r2_score(y_train, pred))*(len(y_train)-1)/(len(y_train)-X_train.shape[1]-1))
    #print("MAE:", metrics.mean_absolute_error(y_train, pred))
    #print("MSE:", metrics.mean_squared_error(y_train, pred))
    mape_value = MAPE(y_train, pred)
    print(f"MAPE: {mape_value:.4f}")
    print("RMSE:", np.sqrt(metrics.mean_squared_error(y_train, pred)))
# Out:
# Model:  LinearRegression
# MAPE: 0.0808
# RMSE: 3.6440877664431994
#
# Model:  DecisionTree
# MAPE: 0.0000
# RMSE: 0.0
#
# Model:  RandomForest
# MAPE: 0.0340
# RMSE: 1.503146246862155
#
# Model:  KNeighbors
# MAPE: 0.0825
# RMSE: 3.5764345868114935
#
# Model:  XGBRegressor
# MAPE: 0.0000
# RMSE: 0.0020573606530424754
#
# Model:  Ridge
# MAPE: 0.0805
# RMSE: 3.6446843640236652
#
# Model:  Lasso
# MAPE: 0.0992
# RMSE: 4.379212911588274
#
# Model:  ElasticNet
# MAPE: 0.0945
# RMSE: 4.154196815472227
#
# Model:  SupportVectorRegressor
# MAPE: 0.0770
# RMSE: 3.7415857458175483

# %% [markdown]
# ### Feature Importance

# %%
rf_model = pipeline_rf.named_steps['rf_classifier']

# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor

# Get feature importances from the model
feature_importances = rf_model.feature_importances_

# Get the names of the features (assuming you have a DataFrame 'X_train')
feature_names = X_train.columns

# Sort feature importances in descending order
sorted_indices = feature_importances.argsort()[::-1]

# Plot feature importances
plt.figure(figsize=(10, 6))
plt.bar(range(len(feature_importances)), feature_importances[sorted_indices])
plt.xticks(range(len(feature_importances)), feature_names[sorted_indices], rotation=90)
plt.xlabel("Feature")
plt.ylabel("Importance")
plt.title("Feature Importance of the full model (Random Forest for compassion satisfaction)")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor

# Assuming you have already trained your model and have feature importances
# stored in 'feature_importances' and feature names in 'feature_names'

# Sort feature importances in descending order
sorted_indices = feature_importances.argsort()[::-1]

# Plot the top 30 feature importances
plt.figure(figsize=(10, 6))
plt.bar(range(40), feature_importances[sorted_indices[:40]])
plt.xticks(range(40), feature_names[sorted_indices[:40]], rotation=90)
plt.xlabel("Feature")
plt.ylabel("Importance")
plt.title("Top 40 Feature Importance (Random Forest)")
plt.tight_layout()
plt.show()

# %%
from sklearn.inspection import PartialDependenceDisplay

# %%
# Create a list of feature indices or feature names you want to analyze
features_to_plot = ['P/N Ratio', 'Age', 'BMI']  

# Create PDPs
pdp_display = PartialDependenceDisplay.from_estimator(rf_model, X, features_to_plot)
pdp_display.plot()

# %%
# Create a list of feature indices or feature names you want to analyze
features_to_plot = ['P/N Ratio', 'Age', 'BMI', 'Support from other Nurses', 'Hospital_DMH']  

# Create PDPs
pdp_display = PartialDependenceDisplay.from_estimator(rf_model, X, features_to_plot)
pdp_display.plot()

# %%
pip install shap
# Out:
# Requirement already satisfied: shap in c:\users\dell\anaconda3\lib\site-packages (0.44.1)
# Requirement already satisfied: scikit-learn in c:\users\dell\anaconda3\lib\site-packages (from shap) (1.2.1)
# Requirement already satisfied: cloudpickle in c:\users\dell\anaconda3\lib\site-packages (from shap) (2.0.0)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\dell\anaconda3\lib\site-packages (from shap) (4.64.1)
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\lib\site-packages (from shap) (1.23.5)
# Requirement already satisfied: scipy in c:\users\dell\anaconda3\lib\site-packages (from shap) (1.10.0)
# Requirement already satisfied: numba in c:\users\dell\anaconda3\lib\site-packages (from shap) (0.56.4)
# Requirement already satisfied: packaging>20.9 in c:\users\dell\anaconda3\lib\site-packages (from shap) (22.0)
# Requirement already satisfied: pandas in c:\users\dell\anaconda3\lib\site-packages (from shap) (2.2.0)
# Requirement already satisfied: slicer==0.0.7 in c:\users\dell\anaconda3\lib\site-packages (from shap) (0.0.7)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\lib\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\dell\anaconda3\lib\site-packages (from numba->shap) (0.39.1)
# Requirement already satisfied: setuptools in c:\users\dell\anaconda3\lib\site-packages (from numba->shap) (65.6.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\anaconda3\lib\site-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\anaconda3\lib\site-packages (from pandas->shap) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\anaconda3\lib\site-packages (from pandas->shap) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from scikit-learn->shap) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\dell\anaconda3\lib\site-packages (from scikit-learn->shap) (1.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import shap

# Calculate SHAP values
explainer_rf = shap.TreeExplainer(rf_model)
shap_values_rf = explainer_rf.shap_values(X_train)

# %%
# Plot feature importance (summary plot)
shap.summary_plot(shap_values_rf, X_train, plot_type="bar")
plt.title("SHAP Feature Importance for Random Forest Regressor")
plt.show()

# %%
# Find the row(s) with the lowest predicted value
lowest_predicted_instance = X_test[y_test == y_test.min()]

# Calculate SHAP values for the lowest predicted instance
shap_values_lowest = explainer_rf.shap_values(lowest_predicted_instance)

# Visualize SHAP values for the lowest predicted instance
shap.initjs()
shap.force_plot(explainer_rf.expected_value, shap_values_lowest, lowest_predicted_instance)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='i4D0V48TNB7T3FSFY4L9S'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 35.50197278911565, "outValue": 33.64, "link": "identity", "featureNames": ["Age", "Highest Educational Level", "No. of Children have", "Monthly Family Income", "Daily travelling Distance", "Mental Health Rate", "Physical Health Rate", "Hours of Sleeping", "Work Experience in this Hospital", "Full work Experience as a Nurse", "Total Working Hours in a Week", "Night Shifts per Month", "Monthly Salary Income", "Relationship with the Superiors", "Support from other Nurses", "Support from the Minor Staff", "Support from the Hospital Administration", "Support from the family", "Support from friends", "Support from the Superiors", "Frequency of involving patient emergencies", "Frequency of exposure to patients death", "Frequency of facing struggles with patients", "Cleanliness", "Safety", "Availability and accessibility", "Sufficient rest areas", "BMI", "P/N Ratio", "Hospital_DMH", "Hospital_LRH", "Hospital_NCI", "Hospital_NHSL", "Main Unit_ICU", "Main Unit_Inward ", "Main Unit_OPD", "Main Unit_Theater", "Gender_Female", "Gender_Male", "Ethnicity_Burgher", "Ethnicity_Muslim", "Ethnicity_Sinhala", "Ethnicity_Tamil", "Marital Status_In a relationship", "Marital Status_Married", "Marital Status_Single", "Marital Status_Spouse has passed away", "Have Children?_No", "Have Children?_Not relevant", "Have Children?_Yes", "Age of the youngest child_1 - 3 yrs", "Age of the youngest child_15 - 18 yrs", "Age of the youngest child_4 - 7 yrs", "Age of the youngest child_8 - 14 yrs", "Age of the youngest child_Above 18 yrs", "Age of the youngest child_Less than 1 yr", "Age of the youngest child_Not relevant", "Transport Mode_Car/Motorcycle", "Transport Mode_Private bus/van", "Transport Mode_Public transport ", "Transport Mode_Walking"], "features": {"0": {"effect": -0.4847083103265481, "value": 55}, "1": {"effect": 0.03471524984309321, "value": 2.0}, "2": {"effect": -0.028627890788891237, "value": 3}, "3": {"effect": -0.06615637701743522, "value": 3.0}, "4": {"effect": 0.055052033039160585, "value": 1.0}, "5": {"effect": 0.04064119232592905, "value": 1.0}, "6": {"effect": 0.1269500126957807, "value": 1.0}, "7": {"effect": -1.9589357342328442, "value": 3.0}, "8": {"effect": -0.26854778217670267, "value": 3.0}, "9": {"effect": -0.04088023588026923, "value": 3.0}, "10": {"effect": 0.07823369565197057, "value": 0.0}, "11": {"effect": -0.04917738485643509, "value": 0.0}, "12": {"effect": 0.023701550291763886, "value": 1.0}, "13": {"effect": 0.24480909025175218, "value": 3.0}, "14": {"effect": 0.2088331813121661, "value": 2.0}, "15": {"effect": 0.041383237249834316, "value": 3.0}, "16": {"effect": 0.38710383857259256, "value": 2.0}, "17": {"effect": 0.020829721870970857, "value": 2.0}, "18": {"effect": -0.17847820803670275, "value": 3.0}, "19": {"effect": -0.05823318760132719, "value": 3.0}, "20": {"effect": -0.05651907748871384, "value": 3.0}, "21": {"effect": -0.013962821681587244, "value": 1.0}, "22": {"effect": 0.2976771236009573, "value": 2.0}, "23": {"effect": 0.01614730235095745, "value": 2.0}, "24": {"effect": 0.2678310278081123, "value": 3.0}, "25": {"effect": 0.10455720203026948, "value": 3.0}, "26": {"effect": -0.02434124238360537, "value": 3.0}, "27": {"effect": -0.07312483109572188, "value": 25.67451917}, "28": {"effect": 0.03396372679553692, "value": 2.25}, "29": {"effect": -0.5249533198525165, "value": false}, "30": {"effect": 0.006120030682973103, "value": false}, "31": {"effect": -0.017940234974500573, "value": false}, "32": {"effect": -0.12452312239150069, "value": true}, "33": {"effect": -0.004953661838852415, "value": false}, "34": {"effect": 0.0794805926072376, "value": true}, "35": {"effect": 0.04608643859938095, "value": false}, "36": {"effect": -0.013583527742073264, "value": false}, "37": {"effect": -0.004354394710773995, "value": true}, "38": {"effect": -0.010463665703933997, "value": false}, "39": {"effect": 3.147360337072975e-05, "va ...
#     document.getElementById('i4D0V48TNB7T3FSFY4L9S')
#   );
# </script>

# %%
# Find the row(s) with the lowest predicted value
lowest_predicted_instance = X_test[y_test == y_test.max()]

# Calculate SHAP values for the lowest predicted instance
shap_values_lowest = explainer_rf.shap_values(lowest_predicted_instance)

# Visualize SHAP values for the lowest predicted instance
shap.force_plot(explainer_rf.expected_value, shap_values_lowest, lowest_predicted_instance)
# Out:
# <div id='iZVI58GXVRIUL7Z4P7I73'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 35.50197278911565, "outValue": 36.88999999999999, "link": "identity", "featureNames": ["Age", "Highest Educational Level", "No. of Children have", "Monthly Family Income", "Daily travelling Distance", "Mental Health Rate", "Physical Health Rate", "Hours of Sleeping", "Work Experience in this Hospital", "Full work Experience as a Nurse", "Total Working Hours in a Week", "Night Shifts per Month", "Monthly Salary Income", "Relationship with the Superiors", "Support from other Nurses", "Support from the Minor Staff", "Support from the Hospital Administration", "Support from the family", "Support from friends", "Support from the Superiors", "Frequency of involving patient emergencies", "Frequency of exposure to patients death", "Frequency of facing struggles with patients", "Cleanliness", "Safety", "Availability and accessibility", "Sufficient rest areas", "BMI", "P/N Ratio", "Hospital_DMH", "Hospital_LRH", "Hospital_NCI", "Hospital_NHSL", "Main Unit_ICU", "Main Unit_Inward ", "Main Unit_OPD", "Main Unit_Theater", "Gender_Female", "Gender_Male", "Ethnicity_Burgher", "Ethnicity_Muslim", "Ethnicity_Sinhala", "Ethnicity_Tamil", "Marital Status_In a relationship", "Marital Status_Married", "Marital Status_Single", "Marital Status_Spouse has passed away", "Have Children?_No", "Have Children?_Not relevant", "Have Children?_Yes", "Age of the youngest child_1 - 3 yrs", "Age of the youngest child_15 - 18 yrs", "Age of the youngest child_4 - 7 yrs", "Age of the youngest child_8 - 14 yrs", "Age of the youngest child_Above 18 yrs", "Age of the youngest child_Less than 1 yr", "Age of the youngest child_Not relevant", "Transport Mode_Car/Motorcycle", "Transport Mode_Private bus/van", "Transport Mode_Public transport ", "Transport Mode_Walking"], "features": {"0": {"effect": -0.40554789345241704, "value": 29}, "1": {"effect": 0.03290802583634074, "value": 1.0}, "2": {"effect": -0.023972979875354745, "value": 999}, "3": {"effect": -0.040477705498717174, "value": 0.0}, "4": {"effect": -0.009587878652026175, "value": 1.0}, "5": {"effect": 0.08808747569149425, "value": 3.0}, "6": {"effect": 0.12107478686448173, "value": 2.0}, "7": {"effect": -0.5055372976758534, "value": 1.0}, "8": {"effect": -0.3286369976828561, "value": 2.0}, "9": {"effect": -0.023381617542545207, "value": 2.0}, "10": {"effect": 0.16092285739164341, "value": 3.0}, "11": {"effect": -0.052933635776424015, "value": 0.0}, "12": {"effect": 0.01528534482330233, "value": 1.0}, "13": {"effect": 0.9197283467071591, "value": 3.0}, "14": {"effect": 0.39365308114363345, "value": 2.0}, "15": {"effect": -0.09001910160174192, "value": 1.0}, "16": {"effect": 0.6224196875773832, "value": 2.0}, "17": {"effect": 0.056368947771131425, "value": 2.0}, "18": {"effect": -0.19378329480923998, "value": 3.0}, "19": {"effect": 0.06822350625613936, "value": 3.0}, "20": {"effect": -0.06378793927525171, "value": 3.0}, "21": {"effect": 0.6428075113849554, "value": 3.0}, "22": {"effect": 0.22873996515737968, "value": 3.0}, "23": {"effect": -0.008753364636917844, "value": 2.0}, "24": {"effect": 0.30973643350869007, "value": 3.0}, "25": {"effect": 0.04962330879721149, "value": 2.0}, "26": {"effect": -0.025940713277404288, "value": 4.0}, "27": {"effect": -0.06884460311550268, "value": 21.08281329}, "28": {"effect": 0.09529323507358811, "value": 0.138888889}, "29": {"effect": -0.4315900783225823, "value": false}, "30": {"effect": 0.02219836321491334, "value": true}, "31": {"effect": -0.01983706170977649, "value": false}, "32": {"effect": 0.06981877473744146, "value": false}, "33": {"effect": 0.02557709336207776, "value": true}, "34": {"effect": -0.07438172457025866, "value": false}, "35": {"effect": 0.05529220123575363, "value": false}, "36": {"effect": -0.01613015908909374, "value": false}, "37": {"effect": -0.004493482801524719, "value": true}, "38": {"effect": -0.00897291969061918, "value": false}, "39": {"effect": 6.1576 ...
#     document.getElementById('iZVI58GXVRIUL7Z4P7I73')
#   );
# </script>

# %%
X_train.shape[1]
# Out:
# 61

# %%
# Initialize the Random Forest Regressor
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)

# Fit the model to the training data
rf_regressor.fit(X_train, y_train)

# Get feature importances
feature_importances = rf_regressor.feature_importances_

# Sort features by importance (descending order)
sorted_indices = np.argsort(feature_importances)[::-1]

# Iterate through features and drop the least important one
for i in sorted_indices:
    # Drop the feature
    X_train.drop(X_train.columns[i], axis=1, inplace=True)
    X_test.drop(X_test.columns[i], axis=1, inplace=True)
    
    # Re-fit the model
    rf_regressor.fit(X_train, y_train)
    
    # Evaluate on the test dataset
    test_rmse = np.sqrt(np.mean((rf_regressor.predict(X_test) - y_test) ** 2))
    print(f"Dropped feature: {X.columns[i]} | Test RMSE: {test_rmse:.2f}")

# Final model after feature selection
final_rf_regressor = rf_regressor

# Evaluate the final model on the test dataset
final_test_rmse = np.sqrt(np.mean((final_rf_regressor.predict(X_test) - y_test) ** 2))
print(f"Final model Test RMSE: {final_test_rmse:.2f}")
# Out:
# Dropped feature: P/N Ratio | Test RMSE: 3.71
# Dropped feature: Age | Test RMSE: 3.77
# Dropped feature: BMI | Test RMSE: 3.75
# Dropped feature: Relationship with the Superiors | Test RMSE: 3.77
# Dropped feature: Hospital_DMH | Test RMSE: 3.75
# Dropped feature: Support from other Nurses | Test RMSE: 3.63
# Dropped feature: Hours of Sleeping | Test RMSE: 3.65
# Dropped feature: Support from the Hospital Administration | Test RMSE: 3.69
# Dropped feature: Total Working Hours in a Week | Test RMSE: 3.68
# Dropped feature: Support from the Superiors | Test RMSE: 3.70
# Dropped feature: Mental Health Rate | Test RMSE: 3.70
# Dropped feature: Frequency of facing struggles with patients | Test RMSE: 3.79
# Dropped feature: Safety | Test RMSE: 3.76
# Dropped feature: Support from the Minor Staff | Test RMSE: 3.72
# Dropped feature: Physical Health Rate | Test RMSE: 3.76
# Dropped feature: Frequency of exposure to patients death | Test RMSE: 3.75
# Dropped feature: Night Shifts per Month | Test RMSE: 3.80
# Dropped feature: Availability and accessibility | Test RMSE: 3.79
# Dropped feature: Frequency of involving patient emergencies | Test RMSE: 3.77
# Dropped feature: Monthly Family Income | Test RMSE: 3.86
# Dropped feature: Daily travelling Distance | Test RMSE: 4.12
# Dropped feature: Sufficient rest areas | Test RMSE: 4.10
# Dropped feature: Support from friends | Test RMSE: 4.11
# Dropped feature: Highest Educational Level | Test RMSE: 4.10
# Dropped feature: Cleanliness | Test RMSE: 4.11
# Dropped feature: Main Unit_Inward  | Test RMSE: 4.02
# Dropped feature: Hospital_NHSL | Test RMSE: 4.04
# Dropped feature: Support from the family | Test RMSE: 4.05
# Dropped feature: Monthly Salary Income | Test RMSE: 4.04
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 16
#      13 # Iterate through features and drop the least important one
#      14 for i in sorted_indices:
#      15     # Drop the feature
# ---> 16     X_train.drop(X_train.columns[i], axis=1, inplace=True)
#      17     X_test.drop(X_test.columns[i], axis=1, inplace=True)
#      19     # Re-fit the model
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5385, in Index.__getitem__(self, key)
#    5382 if is_integer(key) or is_float(key):
#    5383     # GH#44051 exclude bool, which would return a 2d ndarray
#    5384     key = com.cast_scalar_indexer(key)
# -> 5385     return getitem(key)
#    5387 if isinstance(key, slice):
#    5388     # This case is separated from the conditional above to avoid
#    5389     # pessimization com.is_bool_indexer and ndim checks.
#    5390     return self._getitem_slice(key)
#
# IndexError: index 36 is out of bounds for axis 0 with size 32

# %%
# Initialize the Random Forest Regressor
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)

# Fit the model to the training data
rf_regressor.fit(X_train, y_train)

# Sort features by importance (descending order)
feature_importances = rf_regressor.feature_importances_
sorted_indices = feature_importances.argsort()[::-1]

# Iterate through features and drop the least important one
for i in sorted_indices:
    # Drop the feature
    feature_to_drop = X_train.columns[i]
    X_train.drop(columns=[feature_to_drop], inplace=True)
    X_test.drop(columns=[feature_to_drop], inplace=True)
    
    # Re-fit the model
    rf_regressor.fit(X_train, y_train)
    
    # Evaluate on the test dataset
    test_rmse = np.sqrt(np.mean((rf_regressor.predict(X_test) - y_test) ** 2))
    print(f"Dropped feature: {feature_to_drop} | Test RMSE: {test_rmse:.2f}")
# Out:
# Dropped feature: BMI | Test RMSE: 4.03
# Dropped feature: Relationship with the Superiors | Test RMSE: 4.15
# Dropped feature: Mental Health Rate | Test RMSE: 4.11
# Dropped feature: Safety | Test RMSE: 4.12
# Dropped feature: Cleanliness | Test RMSE: 4.09
# Dropped feature: Support from the Superiors | Test RMSE: 4.27
# Dropped feature: Night Shifts per Month | Test RMSE: 4.32
# Dropped feature: Marital Status_Single | Test RMSE: 4.34
# Dropped feature: Monthly Family Income | Test RMSE: 4.33
# Dropped feature: Frequency of exposure to patients death | Test RMSE: 4.63
# Dropped feature: Age of the youngest child_Above 18 yrs | Test RMSE: 4.61
# Dropped feature: Highest Educational Level | Test RMSE: 4.61
# Dropped feature: Age of the youngest child_1 - 3 yrs | Test RMSE: 4.85
# Dropped feature: Marital Status_Married | Test RMSE: 4.86
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[38], line 14
#      11 # Iterate through features and drop the least important one
#      12 for i in sorted_indices:
#      13     # Drop the feature
# ---> 14     feature_to_drop = X_train.columns[i]
#      15     X_train.drop(columns=[feature_to_drop], inplace=True)
#      16     X_test.drop(columns=[feature_to_drop], inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5385, in Index.__getitem__(self, key)
#    5382 if is_integer(key) or is_float(key):
#    5383     # GH#44051 exclude bool, which would return a 2d ndarray
#    5384     key = com.cast_scalar_indexer(key)
# -> 5385     return getitem(key)
#    5387 if isinstance(key, slice):
#    5388     # This case is separated from the conditional above to avoid
#    5389     # pessimization com.is_bool_indexer and ndim checks.
#    5390     return self._getitem_slice(key)
#
# IndexError: index 29 is out of bounds for axis 0 with size 16

# %%
# Initialize the Random Forest Regressor
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)

# Fit the model to the training data
rf_regressor.fit(X_train, y_train)

# Get feature importances
feature_importances = rf_regressor.feature_importances_

# Sort features by importance (descending order)
sorted_indices = np.argsort(feature_importances)[::-1]

# Check if there are features to drop
if len(sorted_indices) > 0:
    # Drop the least important feature
    least_important_index = sorted_indices[-1]
    X_train.drop(X_train.columns[least_important_index], axis=1, inplace=True)
    X_test.drop(X_test.columns[least_important_index], axis=1, inplace=True)
    
    # Re-fit the model
    rf_regressor.fit(X_train, y_train)
    
    # Evaluate on the test dataset
    test_rmse = np.sqrt(np.mean((rf_regressor.predict(X_test) - y_test) ** 2))
    print(f"Dropped feature: {X_train.columns[least_important_index]} | Test RMSE: {test_rmse:.2f}")
else:
    print("No features to drop.")

# Final model after feature selection
final_rf_regressor = rf_regressor

# Evaluate the final model on the test dataset
final_test_rmse = np.sqrt(np.mean((final_rf_regressor.predict(X_test) - y_test) ** 2))
print(f"Final model Test RMSE: {final_test_rmse:.2f}")
# Out:
# Dropped feature: Ethnicity_Sinhala | Test RMSE: 4.04
# Final model Test RMSE: 4.04

# %%
# Initialize the Random Forest Regressor
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)

# Fit the model to the training data
rf_regressor.fit(X_train, y_train)

# Get feature importances
feature_importances = rf_regressor.feature_importances_

# Sort features by importance (descending order)
sorted_indices = np.argsort(feature_importances)[::-1]

# Check if there are features to drop
if len(sorted_indices) > 0:
    # Drop the least important feature
    least_important_index = sorted_indices[-1]
    X_train.drop(X_train.columns[least_important_index], axis=1, inplace=True)
    X_test.drop(X_test.columns[least_important_index], axis=1, inplace=True)
    
    # Re-fit the model
    rf_regressor.fit(X_train, y_train)
    
    # Evaluate on the test dataset
    test_rmse = np.sqrt(np.mean((rf_regressor.predict(X_test) - y_test) ** 2))
    print(f"Dropped feature: {X_train.columns[least_important_index]} | Test RMSE: {test_rmse:.2f}")
else:
    print("No features to drop.")

# Final model after feature selection
final_rf_regressor = rf_regressor

# Evaluate the final model on the test dataset
final_test_rmse = np.sqrt(np.mean((final_rf_regressor.predict(X_test) - y_test) ** 2))
print(f"Final model Test RMSE: {final_test_rmse:.2f}")
# Out:
# Dropped feature: Marital Status_In a relationship | Test RMSE: 4.04
# Final model Test RMSE: 4.04
