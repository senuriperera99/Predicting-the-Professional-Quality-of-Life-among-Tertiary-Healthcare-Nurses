# %%
### Importing Required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/Dell/OneDrive/Desktop/Research Analysis/final_full_dataset_Descriptives.csv")
df.head()
# Out:
#   Hospital Main Unit  Age  Gender Ethnicity Highest Educational Level  \
# 0      DMH   Inward    29  Female   Sinhala        Diploma in Nursing
# 1      DMH   Inward    25  Female   Sinhala        Diploma in Nursing
# 2      DMH   Inward    28  Female   Sinhala             BSc. Nursing
# 3      DMH   Inward    43  Female   Sinhala    BSc. (Hons) in Nursing
# 4      DMH   Inward    28  Female   Sinhala        Diploma in Nursing
#
#       Marital Status Have Children?  No. of Children have  \
# 0            Married            Yes                     1
# 1  In a relationship   Not relevant                   999
# 2            Married             No                   999
# 3            Married            Yes                     3
# 4  In a relationship   Not relevant                   999
#
#   Age of the youngest child  ... Cleanliness     Safety  \
# 0            Less than 1 yr  ...        High       High
# 1              Not relevant  ...   Very high  Very high
# ...

# %%
# CS with Nominal variables

nominal_variables = ['Hospital', 'Main Unit', 'Ethnicity','Gender','Marital Status','Have Children?','Transport Mode']

# Loop through nominal variables and create boxplots
for nominal_var in nominal_variables:
    plt.figure(figsize=(10, 6))
    
    custom_palette = {'#207DFF'}
    
    # Exclude 'Not relevant' category for 'Have Children?' variable
    if nominal_var == 'Have Children?':
        sns.boxplot(x=nominal_var, y='CS_Score', data=df[df[nominal_var] != 'Not relevant'], palette=custom_palette)
        
    else:
        sns.boxplot(x=nominal_var, y='CS_Score', data=df, palette=custom_palette)
        
    plt.xlabel(f'{nominal_var}', fontsize=14)  # Increase X-axis label font size
    plt.ylabel('CS_Score', fontsize=14)  # Increase Y-axis label font size
    plt.xticks(fontsize=12.5)  # Increase font size of category labels on X-axis
    plt.yticks(fontsize=12.5) 
    plt.title(f'Boxplot of CS_Score by {nominal_var}')
    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Scatter plots with trend lines
plt.figure(figsize=(18, 6))

# Scatter plot for Age vs CS_Score with trend line
plt.subplot(1, 3, 1)
sns.scatterplot(x='Age', y='CS_Score', data=df)
sns.regplot(x='Age', y='CS_Score', data=df, scatter=False, color='red')
plt.xlabel(f'Age', fontsize=16)
plt.ylabel('CS_Score', fontsize=16)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
#plt.title('Age vs CS_Score with Trend Line')

# Scatter plot for BMI vs CS_Score with trend line
plt.subplot(1, 3, 2)
sns.scatterplot(x='BMI', y='CS_Score', data=df)
sns.regplot(x='BMI', y='CS_Score', data=df, scatter=False, color='red')
plt.xlabel(f'BMI', fontsize=16)
plt.ylabel('CS_Score', fontsize=16)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
#plt.title('BMI vs CS_Score with Trend Line')

# Scatter plot for P/N Ratio vs CS_Score with trend line
plt.subplot(1, 3, 3)
sns.scatterplot(x='P/N Ratio', y='CS_Score', data=df)
sns.regplot(x='P/N Ratio', y='CS_Score', data=df, scatter=False, color='red')
#plt.title('P/N Ratio vs CS_Score with Trend Line')
plt.xlabel(f'P/N Ratio', fontsize=16)
plt.ylabel('CS_Score', fontsize=16)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Create two separate DataFrames for age groups
df_below_30 = df[df['Age'] < 30]
df_above_30 = df[df['Age'] >= 30]

# Create scatter plots
plt.figure(figsize=(10, 6))

# Scatter plot for age < 30
plt.scatter(df_below_30['Age'], df_below_30['CS_Score'], label='Age < 30', color='blue', alpha=0.7)

# Scatter plot for age >= 30
plt.scatter(df_above_30['Age'], df_above_30['CS_Score'], label='Age >= 30', color='orange', alpha=0.7)

# Customize plot
plt.xlabel('Age')
plt.ylabel('CS_Score')
plt.title('Scatter Plot of CS_Score by Age')
plt.legend()

# Show the plot
plt.show()

# %%
df['Highest Educational Level'].unique()
# Out:
# array(['Diploma in Nursing', 'BSc. Nursing ', 'BSc. (Hons) in Nursing'],
#       dtype=object)

# %%
ordinal_variables = ['Highest Educational Level','Monthly Family Income','Monthly Salary Income', 'Daily travelling Distance', 'Mental Health Rate','Physical Health Rate','Hours of Sleeping','Work Experience in this Hospital','Full work Experience as a Nurse','Total Working Hours in a Week','Night Shifts per Month','Support from other Nurses','Support from the Minor Staff','Support from the Hospital Administration','Support from the family','Support from friends','Support from the Superiors','Frequency of involving patient emergencies','Frequency of exposure to patients death','Frequency of facing struggles with patients','Cleanliness','Safety','Availability and accessibility','Sufficient rest areas']

ordinal_variables_order = {
    'Monthly Family Income': ['Less than Rs.75,000', 'Rs.75,000 – Rs.100,000', 'Rs.100,000 - Rs.200,000','More than Rs.200,000'],
    'Monthly Salary Income': ['Less than 75,000', '75,000 - 100,000', 'More than 100,000'],
    'Daily travelling Distance': ['Less than 1 km', '1 - 5 km', '5 - 10 km','More than 10 km'],
    'Mental Health Rate': ['Poor','Fair','Good','Very Good','Excellent'],
    'Physical Health Rate': ['Poor','Fair','Good','Very Good','Excellent'],
    'Hours of Sleeping': ['Less than 3 hours','3 - 5 hours','5 - 7 hours','More than 7 hours'],
    'Work Experience in this Hospital': ['Less than 5 years','5 - 10 years','10 - 20 years','More than 20 years'],
    'Full work Experience as a Nurse': ['Less than 5 years','5 - 10 years','10 - 20 years','More than 20 years'],
    'Total Working Hours in a Week': ['<42 ','42 - 63','63 - 84','>84 '],
    'Night Shifts per Month': ['<5 ','5 to 10','>10 '],
    'Relationship with the Superiors': ['Very low','Low','Average','High','Very high'],
    'Support from other Nurses': ['Average','High','Very high'],
    'Support from the Minor Staff': ['Very low','Low','Average','High','Very high'],
    'Support from the Hospital Administration': ['Average','High','Very high'],
    'Support from the family': ['Very low','Low','Average','High','Very high'],
    'Support from friends': ['Very low','Low','Average','High','Very high'],
    'Support from the Superiors': ['Very low','Low','Average','High','Very high'],
    'Frequency of involving patient emergencies': ['Low','Average','High','Very high'],
    'Frequency of exposure to patients death': ['Very low','Low','Average','High','Very high'],
    'Frequency of facing struggles with patients': ['Very low','Low','Average','High','Very high'],
    'Cleanliness': ['Very low','Low','Average','High','Very high'],
    'Safety': ['Very low','Low','Average','High','Very high'],
    'Availability and accessibility': ['Very low','Low','Average','High','Very high'],
    'Sufficient rest areas': ['Very low','Low','Average','High','Very high']
}

# Convert ordinal variables to categorical with custom order
for ordinal_var, custom_order in ordinal_variables_order.items():
    df[ordinal_var] = pd.Categorical(df[ordinal_var], categories=custom_order, ordered=True)
    
custom_palette = {'#207DFF'}

for ordinal_var in ordinal_variables:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=ordinal_var, y='CS_Score', data=df, palette=custom_palette)
    plt.xlabel(f'{ordinal_var}', fontsize=16)  # Increase X-axis label font size
    plt.ylabel('CS_Score', fontsize=16)  # Increase Y-axis label font size
    plt.xticks(fontsize=15)  # Increase font size of category labels on X-axis
    plt.yticks(fontsize=15)  # Increase font size of category labels on Y-axis
    plt.show()
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# ...

# %%
category_counts = df['Hours of Sleeping'].value_counts()
print(category_counts)
# Out:
# Hours of Sleeping
# 5 - 7 hours          197
# 3 - 5 hours          120
# Less than 3 hours     43
# More than 7 hours      8
# Name: count, dtype: int64

# %%
category_counts = df['Night Shifts per Month'].value_counts()
print(category_counts)
# Out:
# Night Shifts per Month
# 5 to 10    270
# <5          60
# >10         38
# Name: count, dtype: int64

# %%
CountStatus = df['Main Unit'].value_counts()

# Plot value counts of the 'Main Unit' column
ax = CountStatus.plot(kind='barh')
ax.set_xlabel('Count')
ax.set_ylabel('Main Unit')
ax.set_title('Counts by Main Unit')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame 'df' with columns 'Main Unit' and 'Night Shifts per Month'

# Group by 'Main Unit' and 'Night Shifts per Month' and count occurrences
grouped_df = df.groupby(['Main Unit', 'Night Shifts per Month']).size().unstack(fill_value=0)

# Calculate the total count for each 'Main Unit'
total_counts = grouped_df.sum(axis=1)

# Convert counts to percentages
percentage_df = grouped_df.div(total_counts, axis=0) * 100

# Create a stacked bar chart
ax = percentage_df.plot(kind='bar', stacked=True, figsize=(10, 6))
ax.set_xlabel('Main Unit')
ax.set_ylabel('Percentage')
ax.set_title('Stacked Bar Chart: Night Shifts per Month by Main Unit')

# Add percentage labels to each stack
for container in ax.containers:
    ax.bar_label(container, fmt='%1.1f%%', label_type='edge')

plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_31388\2173406453.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df = df.groupby(['Main Unit', 'Night Shifts per Month']).size().unstack(fill_value=0)
